# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk import ngrams
from collections import Counter
import re
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\minao\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#POS-Tag için bir fonksiyon
def tagging(sent):
    lower_case = sent.lower()
    tokens= nltk.word_tokenize(lower_case)
    tags=nltk.pos_tag(tokens)
    counts = Counter(tag for word,tag in tags)
    print(counts)

# %%
#stopwordsleri ayıklayan fonksiyon
def clean(text):
    wnl=nltk.stem.WordNetLemmatizer()
    stopwords = nltk.corpus.stopwords.words('english')
    words = re.sub(r'[^\w\s]',"",text).split()
    return [wnl.lemmatize(word)for word in words if word not in stopwords]

# %%
#uni-gram veren fonksiyon
def unigram(text):
    unigram=nltk.ngrams(words,1)
    unigramFrequency=Counter(unigram)
    valuesOfUnigram=list(unigramFrequency.values())
    unigramlist=list(unigramFrequency)

    for x in range (0,len(unigramlist)):
        if(valuesOfUnigram[x]>2):
            print(unigramlist[x],"is used",valuesOfUnigram[x],"times")

# %%
#2-gramları veren fonksiyon
def bigram(text):
    biagrams=nltk.ngrams(words,2)
    biagramsFrequency=Counter(biagrams)
    valuesOfBiagrams=list(biagramsFrequency.values())
    biagramlist=list(biagramsFrequency)

    for x in range (0,len(biagramlist)):
        if(valuesOfBiagrams[x]>1):
            print(biagramlist[x],"is used",valuesOfBiagrams[x],"times")

# %%
#3-gramları veren fonksiyon
def trigram(text):
    
    trigrams=nltk.ngrams(words,3)
    trigramsFrequency=Counter(trigrams)
    valuesOfTrigrams=list(trigramsFrequency.values())
    triagramlist=list(trigramsFrequency)

    for x in range (0,len(triagramlist)):
        if(valuesOfTrigrams[x]>1):
            print(triagramlist[x],"is used",valuesOfTrigrams[x],"times")

# %%
f=open(r"C:\Users\minao\Desktop\Corona.txt","r")
corona =f.read()

# %%
words = clean(corona)
words
# Out:
# ['The',
#  'COVID19',
#  'pandemic',
#  'also',
#  'known',
#  'coronavirus',
#  'pandemic',
#  'ongoing',
#  'pandemic',
#  'coronavirus',
#  'disease',
#  '2019',
#  'COVID19',
#  'caused',
#  'severe',
#  'acute',
#  'respiratory',
#  'syndrome',
#  'coronavirus',
#  '2',
#  'SARSCoV2',
#  'first',
#  'identified',
#  'December',
#  '2019',
#  'Wuhan',
#  'China',
#  'The',
#  'World',
#  'Health',
#  'Organization',
#  'declared',
#  'outbreak',
#  'Public',
#  'Health',
#  'Emergency',
#  'International',
#  'Concern',
#  'January',
#  '2020',
#  'pandemic',
#  'March',
#  '2020',
#  'As',
#  '5',
#  'December',
#  '2020',
#  '66',
#  'million',
#  'case',
#  'confirmed',
#  '152',
#  'million',
#  'death',
#  'attributed',
#  'COVID19',
#  'COVID19',
#  'spread',
#  'via',
#  'number',
#  'mean',
#  'primarily',
#  'involving',
#  'saliva',
#  'bodily',
#  'fluid',
#  'excretion',
#  'These',
#  'fluid',
#  'form',
#  'small',
#  'droplet',
#  'aerosol',
#  'spread',
#  'infected',
#  'person',
#  'breathes',
#  'cough',
#  'sneeze',
#  'sings',
#  'speaks',
#  'The',
#  'virus',
#  'may',
#  'also',
#  'spread',
#  'direct',
#  'contact',
#  'unknown',
#  'often',
#  'spread',
#  'via',
#  'fomite',
#  'contaminated',
#  'surfaces89',
#  'The',
#  'exact',
#  'route',
#  'transmission',
#  'rarely',
#  'proven',
#  'conclusively10',
#  'infection',
#  'mainly',
#  'happens',
#  'people',
#  'near',
#  'long',
#  'enough',
#  'known',
#  'close',
#  'contactb',
#  'It',
#  'spread',
#  'early',
#  'two',
#  'day',
#  'infected',
#  'person',
#  'show',
#  'symptom',
#  'presymptomatic',
#  'asymptomatic',
#  'individual',
#  'People',
#  'remain',
#  'infectious',
#  'ten',
#  'day',
#  'moderate',
#  'case',
#  'two',
#  'week',
#  'severe',
#  'case',
#  'Common',
#  'symptom',
#  'include',
#  'fever',
#  'cough',
#  'fatigue',
#  'breathing',
#  'difficulty',
#  'loss',
#  'smell',
#  'taste',
#  'Complications',
#  'may',
#  'include',
#  'pneumonia',
#  'acute',
#  'respiratory',
#  'distress',
#  'syndrome141516',
#  'The',
#  'incubation',
#  'period',
#  'typically',
#  'around',
#  'five',
#  'day',
#  'may',
#  'range',
#  'one',
#  '14',
#  'day',
#  'There',
#  'several',
#  'vaccine',
#  'candidate',
#  'development',
#  'although',
#  'none',
#  'completed',
#  'clinical',
#  'trial',
#  'Although',
#  'work',
#  'underway',
#  'develop',
#  'drug',
#  'inhibit',
#  'virus',
#  'primary',
#  'treatment',
#  'currently',
#  'symptomatic17',
#  'Recommended',
#  'preventive',
#  'measure',
#  'include',
#  'social',
#  'distancing',
#  'wearing',
#  'face',
#  'mask',
#  'public',
#  'ventilation',
#  'airfiltering',
#  'hand',
#  'washing',
#  'covering',
#  'one',
#  'mouth',
#  'sneezing',
#  'coughing',
#  'disinfecting',
#  'surface',
#  'monitoring',
#  'selfisolation',
#  'people',
#  'exposed',
#  'symptomatic',
#  'Authorities',
#  'worldwide',
#  'responded',
#  'implementing',
#  'travel',
#  'restriction',
#  'lockdown',
#  'workplace',
#  'hazard',
#  'control',
#  'facility',
#  'closure',
#  'Many',
#  'place',
#  'also',
#  'worked',
#  'increase',
#  'testing',
#  'capacity',
#  'trace',
#  'contact',
#  'infected',
#  'The',
#  'response',
#  'caused',
#  'global',
#  'social',
#  'economic',
#  'disruption',
#  'including',
#  'largest',
#  'global',
#  'recession',
#  'since',
#  'Great',
#  'Depression18',
#  'It',
#  'led',
#  'postponement',
#  'cancellation',
#  'event',
#  'widespread',
#  'supply',
#  'shortage',
#  'exacerbated',
#  'panic',
#  'buying',
#  'agricultural',
#  'disruption',
#  'food',
#  'shortage',
#  'decreased',
#  'emission',
#  'pollutant',
#  'greenhouse',
#  'gas',
#  'Educational',
#  'institution',
#  'partially',
#  'fully',
#  'closed',
#  'Misinformation',
#  'circulated',
#  'social',
#  'medium',
#  'mass',
#  'medium',
#  'There',
#  'incident',
#  'xenophobia',
#  'discrimination',
#  'Chinese',
#  'people',
#  'perceived',
#  'Chinese',
#  'area',
#  'high',
#  'infection',
#  'rate']

# %%
unigram1 = unigram(corona)
# Out:
# ('The',) is used 6 times
# ('COVID19',) is used 4 times
# ('pandemic',) is used 4 times
# ('also',) is used 3 times
# ('coronavirus',) is used 3 times
# ('2020',) is used 3 times
# ('case',) is used 3 times
# ('spread',) is used 5 times
# ('infected',) is used 3 times
# ('may',) is used 3 times
# ('people',) is used 3 times
# ('day',) is used 4 times
# ('include',) is used 3 times
# ('social',) is used 3 times

# %%
bigram1 = bigram(corona)
# Out:
# ('acute', 'respiratory') is used 2 times
# ('spread', 'via') is used 2 times
# ('infected', 'person') is used 2 times

# %%
POStag = tagging(corona)
# Out:
# Counter({'NN': 82, 'NNS': 59, 'JJ': 53, 'IN': 53, ',': 35, 'CC': 32, 'CD': 26, 'DT': 23, '.': 21, 'VBN': 19, 'RB': 18, 'VBP': 15, 'VBZ': 12, 'VBG': 10, 'VB': 10, 'VBD': 7, 'TO': 6, 'MD': 6, '(': 4, ')': 4, 'PRP': 4, 'NNP': 4, 'WDT': 3, 'WRB': 3, '$': 3, 'JJR': 2, 'EX': 2, '``': 1, "''": 1, 'POS': 1, 'JJS': 1})

# %%
f=open(r"C:\Users\minao\Desktop\Global warming.txt","r")
warming =f.read()

# %%
words = clean(warming)
words
# Out:
# ['Climate',
#  'change',
#  'mean',
#  'difference',
#  'Earths',
#  'global',
#  'climate',
#  'regional',
#  'climate',
#  'time',
#  'Climate',
#  'change',
#  'major',
#  'concern',
#  'especially',
#  'colder',
#  'country',
#  'Climate',
#  'change',
#  'warmer',
#  'colder',
#  'This',
#  'includes',
#  'global',
#  'warming',
#  'global',
#  'cooling',
#  'It',
#  'describes',
#  'change',
#  'state',
#  'atmosphere',
#  'time',
#  'scale',
#  'ranging',
#  'decade',
#  'million',
#  'year',
#  'These',
#  'change',
#  'caused',
#  'process',
#  'inside',
#  'Earth',
#  'force',
#  'outside',
#  'eg',
#  'variation',
#  'sunlight',
#  'intensity',
#  'recently',
#  'human',
#  'activity',
#  'Ice',
#  'age',
#  'prominent',
#  'example',
#  'Climate',
#  'change',
#  'significant',
#  'longterm',
#  'change',
#  'weather',
#  'region',
#  'whole',
#  'Earth',
#  'significant',
#  'period',
#  'time',
#  'Climate',
#  'change',
#  'abnormal',
#  'variation',
#  'climate',
#  'effect',
#  'variation',
#  'part',
#  'Earth',
#  'Examples',
#  'include',
#  'melting',
#  'ice',
#  'cap',
#  'South',
#  'Pole',
#  'North',
#  'Pole',
#  'These',
#  'change',
#  'may',
#  'take',
#  'ten',
#  'hundred',
#  'perhaps',
#  'million',
#  'year',
#  'In',
#  'recent',
#  'use',
#  'especially',
#  'environmental',
#  'policy',
#  'climate',
#  'change',
#  'usually',
#  'refers',
#  'change',
#  'modern',
#  'climate',
#  'see',
#  'global',
#  'warming',
#  'Some',
#  'people',
#  'suggested',
#  'trying',
#  'keep',
#  'Earthâs',
#  'temperature',
#  'increase',
#  '2',
#  'ÂC',
#  '36',
#  'ÂF',
#  'On',
#  'February',
#  '7',
#  '2018',
#  'The',
#  'Washington',
#  'Post',
#  'reported',
#  'study',
#  'scientist',
#  'Germany',
#  'The',
#  'study',
#  'said',
#  'world',
#  'built',
#  'coal',
#  'plant',
#  'currently',
#  'planned',
#  'carbon',
#  'dioxide',
#  'level',
#  'would',
#  'rise',
#  'much',
#  'world',
#  'would',
#  'able',
#  'keep',
#  'temperature',
#  'increase',
#  'limit']

# %%
unigram1 = unigram(warming)
# Out:
# ('Climate',) is used 5 times
# ('change',) is used 11 times
# ('global',) is used 4 times
# ('climate',) is used 5 times
# ('time',) is used 3 times
# ('Earth',) is used 3 times
# ('variation',) is used 3 times

# %%
bigram1 = bigram(warming)
# Out:
# ('Climate', 'change') is used 5 times
# ('time', 'Climate') is used 2 times
# ('global', 'warming') is used 2 times
# ('million', 'year') is used 2 times
# ('These', 'change') is used 2 times
# ('temperature', 'increase') is used 2 times

# %%
trigram1 = trigram(warming)
# Out:
# ('time', 'Climate', 'change') is used 2 times

# %%
POStag = tagging(warming)
# Out:
# Counter({'NN': 58, 'IN': 37, 'DT': 31, 'NNS': 30, 'JJ': 27, '.': 16, 'RB': 9, ',': 9, 'CC': 8, 'VB': 8, 'VBZ': 7, 'MD': 5, 'TO': 5, 'VBN': 4, '(': 4, ')': 4, 'VBP': 4, 'CD': 4, 'VBG': 3, 'VBD': 3, 'POS': 1, 'PRP': 1, 'RBR': 1, 'WDT': 1})
